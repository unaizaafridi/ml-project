# %%
import pandas as pd

x = pd.Series([10, 20, 30, 40, 50])
y = pd.Series([5, 15, 25, 35, 45])  
result = x + y
print(result)
# Out:
# 0    15
# 1    35
# 2    55
# 3    75
# 4    95
# dtype: int64
